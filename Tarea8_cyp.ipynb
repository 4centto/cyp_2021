# %% [markdown]
# <a href="https://colab.research.google.com/github/4centto/cyp_2021/blob/main/Tarea8_cyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Primero se imprime el marco de la parte superior de donde va a estar el nombre
MARCO = "\u20AA"
#058D
#20AA

for i in range(62):
    print(MARCO, end="")
print()
print("\u20AA                                                            \u20AA")

#Impresion del nombre
"""
IIIIIIIIIII   V         V        A        N     N
     I         V       V        A A       NN    N
     I          V     V        A   A      N N   N
     I           V   V        A     A     N  N  N
     I            V V        AAAAAAAAA    N   N N
IIIIIIIIIII        V        A         A   N    NN
"""

#Primera linea
#Impresion de la I
print(MARCO, end="     ")
for i in range(11):
    print("\u058D", end="")

print("   ", end="")
#Impresion de la V
print("\u058D", end="         ")
print("\u058D", end="        ")

#Impresion de la A
print("\u058D", end="        ")

#Impresion de la N
print("\u058D", end="     ")
print("\u058D", end="      ")
print(MARCO)


#Segunda linea
#Impresion de la I
print(MARCO, end="          ")
print("\u058D", end="         ")

#Impresion de la V
print("\u058D", end="       ")
print("\u058D", end="        ")

#Impresion de la A
print("\u058D", end=" ")
print("\u058D", end="       ")

#Impresion de la N
print("\u058D\u058D", end="    ")
print("\u058D", end="      ")
print(MARCO)


#Tercer linea
#Impresion de la I
print(MARCO, end="          ")
print("\u058D", end="          ")

#Impresion de la V
print("\u058D", end="     ")
print("\u058D", end="        ")

#Impresion de la A
print("\u058D", end="   ")
print("\u058D", end="      ")

#Impresion de la N
print("\u058D \u058D", end="   ")
print("\u058D", end="      ")
print(MARCO)


#Cuarta linea
#Impresion de la I
print(MARCO, end="          ")
print("\u058D", end="           ")

#Impresion de la V
print("\u058D", end="   ")
print("\u058D", end="        ")

#Impresion de la A
print("\u058D", end="     ")
print("\u058D", end="     ")

#Impresion de la N
print("\u058D  \u058D", end="  ")
print("\u058D", end="      ")
print(MARCO)


#Quinta linea
#Impresion de la I
print(MARCO, end="          ")
print("\u058D", end="            ")

#Impresion de la V
print("\u058D", end=" ")
print("\u058D", end="        ")

#Impresion de la A
for i in range(9):
    print("\u058D", end="")
print("", end="    ")

#Impresion de la N
print("\u058D   \u058D", end=" ")
print("\u058D", end="      ")
print(MARCO)


#Sexta linea
#Impresion de la I
print(MARCO, end="     ")
for i in range(11):
    print("\u058D", end="")
print("", end="        ")


#Impresion de la V
print("\u058D", end="        ")

#Impresion de la A
print("\u058D", end="         ")
print("\u058D", end="   ")

#Impresion de la N
print("\u058D", end="    ")
print("\u058D\u058D", end="      ")
print(MARCO)

print("\u20AA                                                            \u20AA")

#Impresion del marco final
for i in range(62):
    print(MARCO, end="")
print()
# Out:
# ₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪
# ₪                                                            ₪
# ₪     ֍֍֍֍֍֍֍֍֍֍֍   ֍         ֍        ֍        ֍     ֍      ₪
# ₪          ֍         ֍       ֍        ֍ ֍       ֍֍    ֍      ₪
# ₪          ֍          ֍     ֍        ֍   ֍      ֍ ֍   ֍      ₪
# ₪          ֍           ֍   ֍        ֍     ֍     ֍  ֍  ֍      ₪
# ₪          ֍            ֍ ֍        ֍֍֍֍֍֍֍֍֍    ֍   ֍ ֍      ₪
# ₪     ֍֍֍֍֍֍֍֍֍֍֍        ֍        ֍         ֍   ֍    ֍֍      ₪
# ₪                                                            ₪
# ₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪₪
